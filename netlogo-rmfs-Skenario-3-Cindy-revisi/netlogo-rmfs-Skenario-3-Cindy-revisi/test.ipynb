# %%
x=5
y=x
x=6
print(y)
# Out:
# 5

# %%
import torch
x = torch.tensor([5, 4, 3, 2, 1])
actions = torch.tensor([0, 1, 2, 3, 4])

torch.cat([x, actions], dim=-1)
# Out:
# tensor([5, 4, 3, 2, 1, 0, 1, 2, 3, 4])

# %%
import numpy as np
actions = np.zeros((3,), dtype = np.float32)

# %%
np.exp(-1. * 100 / 0.01)
# Out:
# np.float64(0.0)

# %%
0 + 0.95 * np.exp(-1. * 10000 / 1000)
# Out:
# np.float64(4.312993327436061e-05)

# %%
2 * (0.95 - 0) / 1000
# Out:
# 0.0019

# %%
0.95 - 0.95 * 0.019
# Out:
# 0.93195

# %%
x = np.zeros((60,60))
np.reshape(x, (20, -1)).shape
# Out:
# (20, 180)
